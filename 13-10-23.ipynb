# %%
#import necessary linraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
boston=pd.read_csv("C:/Users/Shubhamparamanik/OneDrive/Desktop/Boston.csv")
boston.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
boston.drop('Unnamed: 0',axis=1,inplace=True)

# %%
boston.describe
# Out:
# <bound method NDFrame.describe of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
correlation_matrix=boston.corr().round(2)
#annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
correlation_matrix=boston.corr().round(2)
#annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True,annot_kws={'size':8},)
# Out:
# <Axes: >

# %%
features=['rm','lstat']
target=['medv']

# %%
x=boston[features[0]]
y=boston[target]

# %%
plt.scatter(x,y)
plt.show()

# %%
x=boston['rm']

# %%
plt.scatter(x,y)
plt.xlabel("Average number of rooms")
plt.ylabel("Median value")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x,y)
plt.xlabel("lower status of population")
plt.ylabel("Median value")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=boston[features[1]]
plt.scatter(x,y)
plt.xlabel("lower status of population")
plt.ylabel("Median value")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_data=boston[features]
new_y=boston[target]
print(new_data.shape)
print(new_y.shape)
# Out:
# (506, 2)
# (506, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
plt.scatter(y_train,y_train_predict)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 plt.scatter(y_train,y_train_predict)
#       2 plt.show()
#
# NameError: name 'y_train_predict' is not defined

# %%
y_train_pred=model.predict(x_train)
print(y_train_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 y_train_pred=model.predict(x_train)
#       2 print(y_train_pred)
#
# NameError: name 'model' is not defined

# %%
print('x_train size:',x_test.shape)
print('x_test size:',x_train.shape)
print('y_train size:',y_test.shape)
print('y_test size:',y_train.shape)
# Out:
# x_train size: (102,)
# x_test size: (404,)
# y_train size: (102, 1)
# y_test size: (404, 1)

# %%
 #create the model
linear=LinearRegression()
#create a train the model with train dataset
model=linear.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 4
#       2 linear=LinearRegression()
#       3 #create a train the model with train dataset
# ----> 4 model=linear.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
result_train=pd.DataFrame()
result_test['actual']=y_test['medv']
result_test['predicte']=y_test_predict
result_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 result_train=pd.DataFrame()
# ----> 2 result_test['actual']=y_test['medv']
#       3 result_test['predicte']=y_test_predict
#       4 result_test
#
# NameError: name 'result_test' is not defined

# %%
print("mean_absolute_error",mean_absolute_error(y_train,y_train_predict))
print("mean_absolute_error",mean_squared_error(y_train,y_train_predict))
print("Root mean squared errror",np.sqrt(mean_squared_error(y_train,y_train_predict)))
print("r2 score",r2_score(y_train,y_train_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print("mean_absolute_error",mean_absolute_error(y_train,y_train_predict))
#       2 print("mean_absolute_error",mean_squared_error(y_train,y_train_predict))
#       3 print("Root mean squared errror",np.sqrt(mean_squared_error(y_train,y_train_predict)))
#
# NameError: name 'y_train_predict' is not defined
