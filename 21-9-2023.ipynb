# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df=pd.read_csv("C:/Users/Shubhamparamanik/OneDrive/Desktop/employees.csv")
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
#df.info()
#df.shape()
df.describe()
df.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
df=df.dropna(axis=0,how='any')

# %%
df.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
df['Senior Management'].unique()
# Out:
# array([True, False], dtype=object)

# %%
mode=df['Senior Management'].mode().values[0]
df['Senior Management'].replace(np.nan,mode,inplace=True)
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_19528\2993287999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Senior Management'].replace(np.nan,mode,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df.head(5)
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_19528\1689300700.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=le.fit_transform(df['Gender'])
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas       1   8/6/1993        12:42 PM   97308    6.945
# 2      Maria       0  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry       1   3/4/2005         1:00 PM  138705    9.340
# 4      Larry       1  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis       1  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# ...

# %%
sns.histplot(x='Salary',data=df,)
plt.show()

# %%
plt.hist(x='Salary',data=df,)
plt.show()

# %%
df['Team'].unique()
# Out:
# array(['Marketing', 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
sns.histplot(x='Team',data=df)
plt.show()

# %%
df.corr()
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_19528\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            Gender    Salary   Bonus %
# Gender   1.000000  0.021822  0.034414
# Salary   0.021822  1.000000 -0.043178
# Bonus %  0.034414 -0.043178  1.000000

# %%
x=np.array([1,3,5,7,9,10,15])
y=np.array([10,20,25,30,40,50,60])
print(np.corrcoef(x,y))
df.corr(method='pearson')
# Out:
# [[1.         0.98497244]
#  [0.98497244 1.        ]]
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_19528\1613477425.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#            Gender    Salary   Bonus %
# Gender   1.000000  0.021822  0.034414
# Salary   0.021822  1.000000 -0.043178
# Bonus %  0.034414 -0.043178  1.000000

# %%
df.cov()
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_19528\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#              Gender        Salary      Bonus %
# Gender     0.250120  3.586765e+02     0.096533
# Salary   358.676487  1.080086e+09 -7959.002650
# Bonus %    0.096533 -7.959003e+03    31.457889

# %%
sns.pairplot(data=df,kind='scatter')
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
