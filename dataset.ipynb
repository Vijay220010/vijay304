# %%
import pandas as pd
data_set= {
"state":['kerala','mizoram','delhi','tripura','uttarakhand','goa','himachal pradesh','assam','maharashtra','punjab'],
"male":[97.4,93.72,93.7,92.18,94.3,92.81,92.9,90.1,90.7,88.5],
"female":[95.2,89.4,82.4,83.15,80.7,81.84,80.5,81.2,78.4,78.5],
}
print(data_set)
# Out:
# {'state': ['kerala', 'mizoram', 'delhi', 'tripura', 'uttarakhand', 'goa', 'himachal pradesh', 'assam', 'maharashtra', 'punjab'], 'male': [97.4, 93.72, 93.7, 92.18, 94.3, 92.81, 92.9, 90.1, 90.7, 88.5], 'female': [95.2, 89.4, 82.4, 83.15, 80.7, 81.84, 80.5, 81.2, 78.4, 78.5]}

# %%
df=pd.DataFrame(data=data_set)

# %%
df
# Out:
#               state   male  female
# 0            kerala  97.40   95.20
# 1           mizoram  93.72   89.40
# 2             delhi  93.70   82.40
# 3           tripura  92.18   83.15
# 4       uttarakhand  94.30   80.70
# 5               goa  92.81   81.84
# 6  himachal pradesh  92.90   80.50
# 7             assam  90.10   81.20
# 8       maharashtra  90.70   78.40
# 9            punjab  88.50   78.50

# %%
plt.scatter(x=df['state'],y=df['male'])
plt.show()

# %%
plt.scatter(x=df['state'],y=df['female'])
plt.show()

# %%
df.plot(kind='bar')
plt.show()
