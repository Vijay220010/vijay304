# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns
df=pd.read_csv("C:/Users/Shubhamparamanik/OneDrive/Desktop/Toyota (1).csv")
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df.corr()
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_15872\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Unnamed: 0     Price       Age  MetColor  Automatic        CC  \
# Unnamed: 0    1.000000 -0.738289  0.907090 -0.078616   0.066299 -0.184490
# Price        -0.738289  1.000000 -0.878407  0.112041   0.033081  0.165067
# Age           0.907090 -0.878407  1.000000 -0.099659   0.032573 -0.120706
# MetColor     -0.078616  0.112041 -0.099659  1.000000  -0.013973  0.029189
# Automatic     0.066299  0.033081  0.032573 -0.013973   1.000000 -0.069321
# CC           -0.184490  0.165067 -0.120706  0.029189  -0.069321  1.000000
# Weight       -0.414577  0.581198 -0.464299  0.057142   0.057249  0.651450
#
#               Weight
# Unnamed: 0 -0.414577
# Price       0.581198
# ...

# %%
df.cov()
# Out:
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_15872\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#               Unnamed: 0         Price           Age    MetColor  Automatic  \
# Unnamed: 0  1.719610e+05 -1.110414e+06   6976.838709  -15.300569   6.308014
# Price      -1.110414e+06  1.315487e+07 -59076.823601  193.860633  27.528947
# Age         6.976839e+03 -5.907682e+04    345.580827   -0.874390   0.136783
# MetColor   -1.530057e+01  1.938606e+02     -0.874390    0.219559  -0.001496
# Automatic   6.308014e+00  2.752895e+01      0.136783   -0.001496   0.052643
# CC         -1.432032e+04  1.120646e+05   -419.406905    2.551120  -2.977170
# Weight     -9.049942e+03  1.109666e+05   -448.498626    1.432394   0.691450
#
#                        CC         Weight
# ...

# %%
x=np.array([1,3,5,7,9,10,15])
y=np.array([10,20,25,30,40,50,60])
print(np.corrcoef(x,y))
df.corr(method='pearson')
# Out:
# [[1.         0.98497244]
#  [0.98497244 1.        ]]
# C:\Users\Shubhamparamanik\AppData\Local\Temp\ipykernel_15872\1613477425.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#             Unnamed: 0     Price       Age  MetColor  Automatic        CC  \
# Unnamed: 0    1.000000 -0.738289  0.907090 -0.078616   0.066299 -0.184490
# Price        -0.738289  1.000000 -0.878407  0.112041   0.033081  0.165067
# Age           0.907090 -0.878407  1.000000 -0.099659   0.032573 -0.120706
# MetColor     -0.078616  0.112041 -0.099659  1.000000  -0.013973  0.029189
# Automatic     0.066299  0.033081  0.032573 -0.013973   1.000000 -0.069321
# CC           -0.184490  0.165067 -0.120706  0.029189  -0.069321  1.000000
# Weight       -0.414577  0.581198 -0.464299  0.057142   0.057249  0.651450
#
# ...

# %%
np.corrcoef(df['Price'],df['Age'])
# Out:
# array([[ 1., nan],
#        [nan, nan]])

# %%
sns.pairplot(data=df,kind='scatter')
